# %% [markdown]
# ## ***Displaying any row within all columns that are null***

# %%
stat = ''

# Displaying any row (instance) within all columns that are null
all_null = str(df_diabetes.isnull().all())

# Status message
stat = 'Null values in all columns of any instance (row)\n\n' + all_null
print(stat)
