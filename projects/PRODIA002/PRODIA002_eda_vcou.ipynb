# %% [markdown]
# ## ***Displaying dataset value counter***

# %%
stat = ''

# Displaying dataset value counter
df_value_counts = df_diabetes.value_counts()

# Status message
stat = 'To check the result, go to df_value_counts dataframe, please'
print(stat)
