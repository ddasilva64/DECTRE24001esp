# %% [markdown]
# ## ***Displaying null values count***

# %%
stat = ''

# Displaying null values count
null_count = str(df_diabetes.isnull().sum())

# Status message
stat = 'Null values count\n\n'
print(stat, null_count)
