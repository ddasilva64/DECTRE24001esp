# %% [markdown]
# ## ***Case 4 (bmi-diabetes)***

# %%
stat = ''

# Graphs of combination 04: bmi-diabetes

ag = sns.jointplot(data = df_diabetes,
              x = 'bmi',
              y = 'diabetes',
              kind = 'reg',
              color = 'grey',
              marker="+")

ag.plot_joint(sns.kdeplot,
              color="black",
              zorder=0,
              levels=6)


bg = sns.JointGrid(data=df_diabetes, x="bmi", y="diabetes")
bg.plot(sns.regplot, sns.boxplot,color = 'grey')

# Status message
stat = 'Jointplot of case 4 (bmi-diabetes), done'
print(stat)
