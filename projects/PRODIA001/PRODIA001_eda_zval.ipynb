# %% [markdown]
# ## ***Display zero values***

# %%
stat = ''

# Display zero values
#   if there are missing values, then replace to zero
#   that means that it counts zeroes
zero_values = str(df_diabetes.iloc[:, 0:8].replace(to_replace=[0], value=np.nan).isna().sum().reset_index(name = 'missing_values').rename(columns={"index": "variable"}).assign( percentage = lambda df_reset: round(df_reset.missing_values/len(df_diabetes)*100,2)))

# Status message
stat = 'Display zero values\n\n' + zero_values
print(stat)
