# %% [markdown]
# ## ***Display any row that has any column with null values***

# %%
stat = ''

# Display any row (instance) that has any column with null values

any_null = str(df_diabetes.isnull().any())

# Status message
stat = 'Null values ​​in some columns of some instance (row)\n\n' + any_null
print(stat)
