# %% [markdown]
# ### ***Individual variable analysis (Variable summary, after outlier treatment)***

# %%
stat = ''

# Variable summary
df_emb  = funcResumen_Variables(df_diabetes['pregnancies'],  ' ')
df_glu  = funcResumen_Variables(df_diabetes['glucose'],      'X')
df_pre  = funcResumen_Variables(df_diabetes['pressure'],     'X')
df_imc  = funcResumen_Variables(df_diabetes['bmi'],          'X')
df_ant  = funcResumen_Variables(df_diabetes['pedigree'],     ' ')
df_eda  = funcResumen_Variables(df_diabetes['age'],          ' ')
df_dia  = funcResumen_Variables(df_diabetes['diabetes'],     ' ')

df_resumen = {
'type':                  [df_emb[0], df_glu[0], df_pre[0], df_imc[0], df_ant[0], df_eda[0], df_dia[0]],
'total':                 [df_emb[1], df_glu[1], df_pre[1], df_imc[1], df_ant[1], df_eda[1], df_dia[1]],
'zeroes':                [df_emb[2], df_glu[2], df_pre[2], df_imc[2], df_ant[2], df_eda[2], df_dia[2]],
'not zeroes':            [df_emb[3], df_glu[3], df_pre[3], df_imc[3], df_ant[3], df_eda[3], df_dia[3]],
'% not zeroes':          [df_emb[4], df_glu[4], df_pre[4], df_imc[4], df_ant[4], df_eda[4], df_dia[4]],
'should not have zeroes':[df_emb[5], df_glu[5], df_pre[5], df_imc[5], df_ant[5], df_eda[5], df_dia[5]],
'mode':                  [df_emb[6], df_glu[6], df_pre[6], df_imc[6], df_ant[6], df_eda[6], df_dia[6]]
             }

indexes = ['pregnancies', 'glucose', 'pressure', 'bmi', 'pedigree', 'age', 'diabetes']
columns = ['type', 'total', 'zeroes', 'not zeroes', '% not zeroes', 'should not have zeroes', 'mode']

df_resumen = pd.DataFrame(data=df_resumen, index=indexes, columns=columns, dtype=str)
df_resumen = df_resumen.transpose()

# Status message
stat = 'To check the result, go to df_resumen dataframe, please'
print(stat)
