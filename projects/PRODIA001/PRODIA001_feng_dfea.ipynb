# %% [markdown]
# ### ***Feature Engineering (Delete features with > 20% outliers)***

# %%
stat = ''

# Delete features with > 20% outliers
df_diabetes.drop(columns=['skinfold', 'insulin'], inplace=True)

# Status message
stat = 'To check useful features go to df_diabetes dataframe, please'
print(stat)
