# %% [markdown]
# ## ***Missing values ​​graph***

# %%
stat = ''
# Missing values ​​graph
#   if there are missing values, then total != total row number
miss.bar(df_diabetes);

# Status message
stat = 'Missing values ​​graph, done'
miss.bar(df_diabetes)
print(stat)
