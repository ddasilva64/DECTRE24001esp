# %% [markdown]
# ## ***Required libraries***

# %%
# Importing required libraries
from gc                       import collect                                    # garbage collector to free memory
from warnings                 import filterwarnings                             # handling warnings
import re                                                                       # regular expressions
import numpy                  as np                                             # Linear Algebra
import pandas                 as pd                                             # data processing, CSV file I/O
import missingno              as miss                                           # missing values
import matplotlib.pyplot      as plt                                            # data visualization
from matplotlib.ticker        import FuncFormatter                              # custom format
from matplotlib.ticker        import FormatStrFormatter                         # format with a string
from mpl_toolkits.mplot3d     import Axes3D                                     # 3D axis module
from matplotlib.colors        import ListedColormap                             # colormap for scatter plot
import seaborn                as sns                                            # statistical data visualization
import plotly.express         as px                                             # interactive visualizations
from scipy                    import stats                                      # statistical functions
from scipy.stats              import zscore                                     # z-score
from scipy.stats              import f_oneway                                   # one-way ANOVA test
from statsmodels.formula.api  import ols                                        # Ordinary Least Squares (OLS) regression models
from scipy.stats.mstats       import winsorize                                  # winsorize function to handle outliers
from sklearn                  import metrics                                    # more than 40 metrics available
from sklearn.ensemble         import RandomForestClassifier                     # random forest classifier
from sklearn.tree             import DecisionTreeClassifier, plot_tree          # DecisionTree and plot tree for decision trees
from sklearn.model_selection  import train_test_split                           # split data into training and test sets
from sklearn.metrics          import accuracy_score                             # evaluate the accuracy of the classifier
from sklearn.preprocessing    import LabelEncoder                               # encode categorical labels into numeric labels
from sklearn.preprocessing    import OneHotEncoder, StandardScaler              # categorical variables in numerical format and standardize the characteristic variables
from sklearn.metrics          import mean_squared_error                         # mean square error (MSE) between actual and predicted values
from sklearn.model_selection  import GridSearchCV                               # hyperparameter optimization
from sklearn.metrics          import r2_score                                   # evaluate performance
from sklearn.ensemble         import ExtraTreesClassifier                       # feature selection
import itertools                                                                # makes it possible to build specialized, succinct and efficient tools
from itertools                import cycle, combinations                        # generating combinations
from tabulate                 import tabulate                                   # format tables
from io                       import StringIO                                   # handling different types of I/O
from IPython.display          import display, HTML, display_html, clear_output  # display html content
import os                                                                       # use OS dependent features
from scipy.stats              import skew                                       # asymmetry calculation
from scipy.stats              import kurtosis                                   # kurtosis calculation
import math                                                                     # mathematical functions defined in the C standard
from math                     import sqrt                                       # square root
from scipy.stats.mstats       import winsorize                                  # winsorization algorithm for dealing with outliers
from sklearn.preprocessing    import QuantileTransformer                        # modeling
from sklearn.model_selection  import train_test_split                           # cross validation
from sklearn.metrics          import classification_report                      # classification report
from google.colab             import drive                                      # mount drive
from IPython.display          import YouTubeVideo                               # YouTube videos
from sklearn                  import tree                                       # Tree representation

# Status message
print('Required libraries imported')
# Out:
# 60
