# %% [markdown]
# ### ***Scatter plot graphics***

# %%
stat = ''

# Scatter plot graphics
sns.pairplot(df_diabetes,hue='diabetes')

# Status message
stat = 'Scatter plot graphics, done'
print(stat)
