# %% [markdown]
# ## ***Classification report***

# %%
stat = ''

# Classification report
class_rep = classification_report(y_test_diabetes, y_test_pred_diabetes)

# Status message
stat = 'Classification report (metrics)\n' + class_rep
print(stat)
