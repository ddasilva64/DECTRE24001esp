# %% [markdown]
# ## ***Object shape analysis***

# %%
stat = ''

# Object shape analysis
df_shape_feat = str(df_diabetes.shape[0])
df_shape_targ = str(df_diabetes.shape[1])
df_shape      = str(df_diabetes.shape)

# Status message
stat = 'The dataset contains ' + df_shape_feat + ' rows and ' + df_shape_targ + ' columns ' + df_shape
print(stat)
